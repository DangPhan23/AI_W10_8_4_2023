# %% [markdown]
# <a href="https://colab.research.google.com/github/DangPhan23/AI_W10_8_4_2023/blob/main/Khuon_Mat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
folder ='/content/drive/MyDrive/my_pic'
for i in range(60):
  plt.subplot(10,6,i+1)
  filename= folder+'/DUONGDANG'+str(i)+'.jpg'
  img=imread(filename)
  plt.imshow(img)
plt.show()
filename= folder+'/DUONGDANG'+str(0)+'.jpg'
img=imread(filename)
plt.imshow(img)

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.utils import load_img,img_to_array
folder ='/content/drive/MyDrive/my_pic/'
photos,label=list(),list()
for file in listdir(folder):
  output=0.0
  if file.startswith('Dung'):
    output=1
  if file.startswith('DUONGDANG'):
    output=2
  img=load_img(folder+file)
  photo=img_to_array(img)
  photos.append(photo)
  label.append(output)
photos=asarray(photo)
labels=asarray(labels)
print(photos.shape,labels.shape)
save('Dang_Dung_photos.npy',photos)
save('Dang_Dung_labels.npy',labels)
